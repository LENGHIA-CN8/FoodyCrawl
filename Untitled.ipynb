# %%
import pandas as pd

# %%
comment = pd.read_csv("./OUTPUT-1/Comment.csv")

# %%
comment
# Out:
#         RevId    UserId   ResId  \
# 0     1942111    372656  200790
# 1     2156575   1564023  200790
# 2     2655734  12260513  200790
# 3     2233082   8296274  200790
# 4     1158517   1783611  200790
# ...       ...       ...     ...
# 3130  3307802  17533802  966973
# 3131  3854659  18762268  966973
# 3132   371978    910285  100842
# 3133   541381    395412  100842
# 3134   879089   1726428  100842
#
#                                                 Comment  \
# 0     Quán nằm trên đường Trung Hòa, dễ tìm, nhân vi...
# 1     Vì nhà mình tổ chức tiệc có 11 người nên là tr...
# 2     Mình đặt chả cá Anh Vũ Trung Hoà lần đầu vì th...
# 3     ✔️ Vị trí\nMặt đường Trung Hoà nên khá dễ tìm\...
# 4     Thích ăn chả cá ở đây, thịt ướp vừa vặn cá giò...
# ...                                                 ...
# 3130  Lần đầu tiêu riview quán vì thất vọng rất nhiề...
# 3131  Là một khách tủ mỗi tuần đóng họ 1 lần nên bài...
# 3132  Công ty tớ gần đây nhân ngày trời mưa rủ nhau ...
# ...

# %%
user = pd.read_csv("./OUTPUT-1/User.csv")

# %%
user1 = user.drop_duplicates(subset=['UserId'])

# %%
user1
# Out:
#         UserId  Total_reviews  Followers
# 0       372656            450        251
# 1      1564023             43         56
# 2     12260513              3          0
# 3      8296274             30          3
# 4      1783611             37        201
# ...        ...            ...        ...
# 3130  17533802              1          0
# 3131  18762268              1          0
# 3132    910285              9          1
# 3133    395412            175         16
# 3134   1726428             15          1
#
# [3135 rows x 3 columns]

# %%
restaurant = pd.read_csv("./OUTPUT-1/Restaurant.csv")

# %%
restaurant = restaurant.drop_duplicates(subset=['ResId'])

# %%
restaurant
# Out:
#        ResId  Rating                                streetAddress  \
# 0     200790     8.4                                103 Trung Hoà
# 5      44727     6.2                                      Trần Vĩ
# 6     995584     7.4                                  163 Tô Hiệu
# 7     109338     7.2                                   66 Duy Tân
# 9     221742     1.0           C03 Ngõ 69 Dương Khuê, P. Mai Dịch
# ...      ...     ...                                          ...
# 3124  714755     7.4                                 37 Trung Hòa
# 3125  201735     4.8                           167 Nguyễn Ngọc Vũ
# 3127  689038     9.6  Tầng 4-1, Tòa V4, Home City, 177 Trung Kinh
# 3129  966973     8.4                  6b Ngõ 92 Nguyễn Khánh Toàn
# 3132  100842     8.2                            39 Trần Kim Xuyến
#
#            district  region  Res_pos_score  Res_price_score  Res_food_score  \
# 0     Quận Cầu Giấy  Hà Nội            8.3              8.2             7.9
# ...
